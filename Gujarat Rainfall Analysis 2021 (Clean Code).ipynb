# %%
import pandas as pd
import numpy as np

data=pd.read_excel('D:\Data Sets\\GujaratMonsoon_2021.xlsx')

# %%
data.head(10)
# Out:
#       District  Average Rainfall  Rainfall Received  Percent  \
# 0        Kutch               442                494   111.69
# 1        Patan               593                449    75.59
# 2  Banaskantha               626                442    70.52
# 3     Mahesana               724                560    77.34
# 4  Sabarkantha               852                603    70.76
# 5     Aravalli               875                547    62.54
# 6  Gandhinagar               765                544    71.07
# 7    Ahmedabad               689                526    76.35
# 8        Kheda               821                662    80.69
# 9        Anand               763                813   106.50
#
#    Deviation from 100% Classification           Region
# 0                11.69         Normal            Kutch
# 1               -24.41      Deficient    North Gujarat
# 2               -29.48      Deficient    North Gujarat
# 3               -22.66      Deficient    North Gujarat
# ...

# %%
data.describe()
# Out:
#        Average Rainfall  Rainfall Received     Percent  Deviation from 100%
# count         33.000000          33.000000   33.000000            33.000000
# mean         913.151515         840.212121   93.838788            -6.161212
# std          455.288035         413.623452   22.059133            22.059133
# min          442.000000         442.000000   62.540000           -37.460000
# 25%          677.000000         544.000000   75.590000           -24.410000
# 50%          743.000000         684.000000   94.670000            -5.330000
# 75%          929.000000         955.000000  105.830000             5.830000
# max         2372.000000        2294.000000  142.890000            42.890000

# %%
data.index
# Out:
# RangeIndex(start=0, stop=33, step=1)

# %%
kutch=data.iloc[0]
kutch
# Out:
# District                Kutch
# Average Rainfall          442
# Rainfall Received         494
# Percent                111.69
# Deviation from 100%     11.69
# Classification         Normal
# Region                  Kutch
# Name: 0, dtype: object

# %%
north_guj=data.iloc[1:7]
north_guj
# Out:
#       District  Average Rainfall  Rainfall Received  Percent  \
# 1        Patan               593                449    75.59
# 2  Banaskantha               626                442    70.52
# 3     Mahesana               724                560    77.34
# 4  Sabarkantha               852                603    70.76
# 5     Aravalli               875                547    62.54
# 6  Gandhinagar               765                544    71.07
#
#    Deviation from 100% Classification         Region
# 1               -24.41      Deficient  North Gujarat
# 2               -29.48      Deficient  North Gujarat
# 3               -22.66      Deficient  North Gujarat
# 4               -29.24      Deficient  North Gujarat
# 5               -37.46      Deficient  North Gujarat
# 6               -28.93      Deficient  North Gujarat
